# %%
# Импорт библиотек
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sqlalchemy import create_engine
from datetime import datetime, timedelta, timezone

# Вывод всей таблицы формата pandas 
pd.set_option('display.max_columns', None)

# %%
# Информация аккаунта базы данных 
# host: rc1a-iqgm3dtfb6m2f7bc.mdb.yandexcloud.net 
# port: 6432 
# user: admininterfacefetcher 
# password: #WkQb}ssu4Wz 
# database: lendsbayapi 

# Варианты диалектов 
# psycopg2 
# pg8000 

# Формула ключа 
# [DB_FLAVOR]+[DB_PYTHON_LIBRARY]://[USERNAME]:[PASSWORD]@[DB_HOST]:[PORT]/[DB_NAME] 

# Считывает SQL при помощи Python
db_uri = 'postgresql+psycopg2://admininterfacefetcher:#WkQb}ssu4Wz@rc1a-iqgm3dtfb6m2f7bc.mdb.yandexcloud.net:6432/lendsbayapi' 
engine = create_engine(db_uri, echo=True)




# --- Запросы необходимых таблиц ---

# Таблица с информацией о пользователях 
users = pd.read_sql_table('users', engine)

# Таблица с ПД о пользователях 
user_info = pd.read_sql_table('userinfo', engine)

# Таблица с логинами пользователей
user_session = pd.read_sql_table('user_session', engine)

# Таблица с информацией о счетах
virtual_accounts = pd.read_sql_table('virtual_accounts', engine)

# Таблица с информацией о платежах
loans = pd.read_sql_table('loans', engine)

# Таблица с информацией о платежах по займам
loan_payments = pd.read_sql_table('loan_payments', engine)

# Таблица с платежами по займам
payments = pd.read_sql_table('payments', engine)

# Таблица с операциями пользователей
operations = pd.read_sql_table('operations', engine)

# Таблица с транзакциями пользователей
transactions = pd.read_sql_table('transactions', engine)

# Таблица с информацией о кредитном рейтинге пользователей
score = pd.read_sql_table('score', engine)

# Таблица кредитными историями пользователей
equifax_entries = pd.read_sql_table('equifax_entries', engine)

# Таблица c внутренними отзывами о клиентах
reviews = pd.read_sql_table('reviews', engine)

# Таблица с инвесторами займов
loan_investors = pd.read_sql_table('loan_investors', engine)

# Таблица с выплатами инвесторам
loan_investors_payments = pd.read_sql_table('loan_investors_payments', engine)
# Out:
# 2022-03-30 18:17:13,361 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2022-03-30 18:17:13,364 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-03-30 18:17:13,401 INFO sqlalchemy.engine.Engine select current_schema()
# 2022-03-30 18:17:13,402 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-03-30 18:17:13,421 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2022-03-30 18:17:13,422 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-03-30 18:17:13,468 INFO sqlalchemy.engine.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind in ('r', 'p')
# 2022-03-30 18:17:13,468 INFO sqlalchemy.engine.Engine [generated in 0.00097s] {'schema': 'public'}
# 2022-03-30 18:17:13,509 INFO sqlalchemy.engine.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind IN ('v', 'm')
# ...

# %%
# ---



# --- Форматирование таблиц для отчётности --- 

# ---
# Выделение таблиц для отчётности
user_session_report = user_session
users_report, user_info_report, virtual_accounts_report = users, user_info, virtual_accounts
loans_report, loans_p2p_report, loans_f2f_report = loans, loans_p2p, loans_f2f
loan_payments_report, payments_report, operations_report = loan_payments, payments, operations
score_report, equifax_entries_report = score, equifax_entries
# Out:
# C:\Users\Lendsbay2\AppData\Local\Temp\ipykernel_9820\50163076.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loans_p2p['sum_with_comm'] = loans_p2p['sum'] + loans_p2p['commission']
