# %%
import main_module
# %run C:\Users\Lendsbay2\Documents\GitHub\lendsbay-package\db_preproc\start_db.ipynb
# %run C:\Users\Lendsbay2\Documents\GitHub\lendsbay-package\db_preproc\preproc_db.ipynb
# %run C:\Users\Lendsbay2\Documents\GitHub\lendsbay-package\db_preproc\ratings.ipynb
# Out:
# 2022-04-14 12:23:39,837 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2022-04-14 12:23:39,840 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-04-14 12:23:39,882 INFO sqlalchemy.engine.Engine select current_schema()
# 2022-04-14 12:23:39,883 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-04-14 12:23:39,899 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2022-04-14 12:23:39,900 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-04-14 12:23:39,928 INFO sqlalchemy.engine.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind in ('r', 'p')
# 2022-04-14 12:23:39,929 INFO sqlalchemy.engine.Engine [generated in 0.00076s] {'schema': 'public'}
# 2022-04-14 12:23:39,956 INFO sqlalchemy.engine.Engine SELECT c.relname FROM pg_class c JOIN pg_namespace n ON n.oid = c.relnamespace WHERE n.nspname = %(schema)s AND c.relkind IN ('v', 'm')
# ...
